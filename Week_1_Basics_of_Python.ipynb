# %% [markdown]
# <a href="https://colab.research.google.com/github/adammcodes/codecademy-ai-bootcamp/blob/main/Week_1_Basics_of_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Bob"
age = 25
student = True
print(name, age, student)
# Out:
# Bob 25 True

# %%
a = 25
f = 3.14
s = "hello"
b = True
print(type(a), type(f), type(s), type(b))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %%
a = 10
b = 3
print(a+b)
print(a-b)
# Out:
# 13
# 7

# %%
a = 10
b = 3
print(a*b) # multiply
print(a/b) # division
print(a//b) # floor division
# Out:
# 30
# 3.3333333333333335
# 3

# %%
a = 10
square = a**2
cube = a**3
print(square, cube)
# Out:
# 100 1000

# %%
class = 10 # Error because class is a reserved keyword
my_class = 10 # this works
# Out:
#   File "/tmp/ipykernel_197/669603604.py", line 1
#     class = 10 # Error because class is a reserved keyword
#           ^
# SyntaxError: invalid syntax

# %%
name = "Alex"
age = 20
print(name, "is", age, "years old") # use commas for concatenation
# Out:
# Alex is 20 years old

# %%
# re-assignment
x = 5
print("x =", x)
x = x + 2
print("+ 2 =", x)
x = x * 3
print("* 3 =", x)
x = x - 4
print("- 4 =", x)
# Out:
# x = 5
# + 2 = 7
# * 3 = 21
# - 4 = 17

# %%
i = 10
f = 10.0
sum = i + f # integer + float = float
print(sum)
print(type(sum))
# Out:
# 20.0
# <class 'float'>

# %%
a = 12
b = 5
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a ** b)
# Out:
# 17
# 7
# 60
# 2.4
# 2
# 248832
