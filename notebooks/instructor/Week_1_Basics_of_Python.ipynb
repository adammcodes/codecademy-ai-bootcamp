# %%
a = 10
print(a)
a = 20
print(a)
# Out:
# 10
# 20

# %%
b = "Hello"
print(b)
# Out:
# Hello

# %%
a = 20
type(a)
# Out:
# int

# %%
a = "20"
type(a)
# Out:
# str

# %%
a = 20.0
type(a)
# Out:
# float

# %%
# Operators

a = 5
b = 3
a+b
# Out:
# 8

# %%
a-b
# Out:
# 2

# %%
a*b
# Out:
# 15

# %%
a/b
# Out:
# 1.6666666666666667

# %%
a = 10
b = 3
print(a/b)
print(a//b)
print(a%b)
# Out:
# 3.3333333333333335
# 3
# 1

# %%
24-(4*2)+2%2-((10%3)-(58//11)+60)
# Out:
# -40

# %%
(4+(8**2)-3**2%1)
# Out:
# 68
